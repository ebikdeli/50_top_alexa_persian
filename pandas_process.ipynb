# %%
import pandas as pd

# %%
# df_sites = pd.read_json('./site_desc.json', lines=True, orient='records')
df_sites = pd.read_json('./site_desc.txt', lines=True, orient='records')
df_sites
# Out:
#                                       www.google.com  \
# 0  Search the world's information, including webp...
#
#                             www.aparat.com  \
# 0  \n        آپارات - سرویس اشتراک ویدیو\n
#
#                                     www.digikala.com  \
# 0  هر آنچه که نیاز دارید با بهترین قیمت از دیجی‌ک...
#
#                                     www.varzesh3.com  \
# 0  پایگاه اطلاع رسانی ورزشی برای فارسی زبانان كه ...
#
#                                   www.telewebion.com         www.shaparak.ir  \
# 0  تلوبیون مرجع پخش زنده و آرشیو شبکه های صدا و س...  صفحه اصلی - شرکت شاپرک
#
#          www.divar.ir  www.wikipedia.org www.donya-e-eqtesad.com  \
# 0  CONNECTION TIMEOUT  CONNECTION FAILED      CONNECTION TIMEOUT
#
#                                     www.torob.com  ...  \
# 0  جستجوی کمترین قیمت در فروشگاه‌های معتبر ایرانی  ...
#
#                                www.stackoverflow.com  \
# 0  Stack Overflow is the largest, most trusted on...
#
# ...
